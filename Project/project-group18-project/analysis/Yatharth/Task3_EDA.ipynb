# %% [markdown]
# # Task 3 EDA
#
# In this task I have taken help from [this link](https://towardsai.net/p/data-analysis/exploratory-data-analysis-in-python-ebdf643a33f6) which has helped me through the steps of Exploratory Data Analysis.
#
# ###### All the required references are on the main page READ.ME file

# %% [markdown]
# ## Identification of data and variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
sns.set_theme(font_scale=1)

# %%
import pandas as pd
def load_and_process(path):
    # Method Chain 1 (Load data and deal with missing data)    

    df1 = (
        pd.read_csv(path)
        .sort_values("Date", ascending=True)
        .dropna()
       .assign(Percentage_Positive_Population=df["Total_Cases"] / df["Population"] * 100)
       
    )
    
    df2 = (
        df1
        df.drop("Active_Cases",axis=1,inplace=True)
        df.drop("Serious_or_Critical",axis=1,inplace=True)
        df.drop("Total_Tests",axis=1,inplace=True)
    
    )
    

    # Make sure to return the latest dataframe

    return df1

# %%
path = r"../../data/processed/worldometers_snapshots_April18_to_September20.csv"

df = load_and_process(path)

df
# Out:
#              Date      Country  Population  Total_Cases  Total_Deaths  \
# 0      2020-04-18          USA   331441624     738792.0       39014.0
# 138    2020-04-18    Sri Lanka    21433620        254.0           7.0
# 140    2020-04-18      Estonia     1326739       1512.0          38.0
# 141    2020-04-18        Malta      441811        426.0           3.0
# 144    2020-04-18      Iceland      341743       1760.0           9.0
# ...           ...          ...         ...          ...           ...
# 33086  2020-09-20      Lebanon     6818397      29303.0         297.0
# 33088  2020-09-20  El Salvador     6493618      27553.0         811.0
# 33089  2020-09-20    Australia    25566037      26898.0         849.0
# 33091  2020-09-20     S. Korea    51279260      22975.0         383.0
# 33093  2020-09-20     Cameroon    26689491      20431.0         416.0
#
#        Total_Recovered  Percentage_Positive_Population
# 0              68269.0                        0.222903
# ...

# %%
path = r"../../data/processed/worldometers_snapshots_April18_to_September20.csv"

df = load_and_process(path)

df
# Out:
#              Date      Country  Population  Total_Cases  Total_Deaths  \
# 0      2020-04-18          USA   331441624     738792.0       39014.0
# 138    2020-04-18    Sri Lanka    21433620        254.0           7.0
# 140    2020-04-18      Estonia     1326739       1512.0          38.0
# 141    2020-04-18        Malta      441811        426.0           3.0
# 144    2020-04-18      Iceland      341743       1760.0           9.0
# ...           ...          ...         ...          ...           ...
# 33086  2020-09-20      Lebanon     6818397      29303.0         297.0
# 33088  2020-09-20  El Salvador     6493618      27553.0         811.0
# 33089  2020-09-20    Australia    25566037      26898.0         849.0
# 33091  2020-09-20     S. Korea    51279260      22975.0         383.0
# 33093  2020-09-20     Cameroon    26689491      20431.0         416.0
#
#        Total_Recovered  Percentage_Positive_Population
# 0              68269.0                        0.222903
# ...

# %% [markdown]
# ## Looking into our data and Analyzing teh basic metrics
#
# For the analysis we need to keep the number of countries and other aspects in our mind. This will help us in case we need tto apply some mathematical operations for drawing our conclusions.

# %%
## Describing all numeric data
df.describe(include=[np.number])
df
# Out:
#          Population   Total_Cases   Total_Deaths  Total_Recovered  \
# count  1.802500e+04  1.802500e+04   18025.000000     1.802500e+04
# mean   4.672500e+07  1.074471e+05    4072.359667     6.882971e+04
# std    1.563426e+08  4.791362e+05   16179.436927     3.047804e+05
# min    4.993000e+03  1.100000e+01       0.000000     2.000000e+00
# 25%    2.964505e+06  1.805000e+03      28.000000     9.080000e+02
# 50%    9.939517e+06  8.987000e+03     184.000000     4.703000e+03
# 75%    3.700833e+07  4.561300e+04    1150.000000     2.701700e+04
# max    1.439324e+09  7.009844e+06  204118.000000     4.392650e+06
#
#        Percentage_Positive_Population
# count                    18025.000000
# mean                         0.320773
# std                          0.535814
# min                          0.000088
# 25%                          0.032161
# 50%                          0.118520
# 75%                          0.368141
# max                          4.394037

# %%
## Describing all categorical Coloumns:
df.describe(include=[object])
#this shows us that we are dealing with 18025 dates and 18025 countries. This occurs because we have 6 months data
#
# Out:
#               Date  Country
# count        18025    18025
# unique         156      156
# top     2020-05-02  Germany
# freq           121      156

# %%
# Now for our last step for setup, Iwould liek to convert my "Date coloumn" to an object so that we can choose a spefic 
#time frame for our Analysis 
df["Date"]=pd.to_datetime(df["Date"])
df.head()
# Out:
#           Date    Country  Population  Total_Cases  Total_Deaths  \
# 0   2020-04-18        USA   331441624     738792.0       39014.0
# 138 2020-04-18  Sri Lanka    21433620        254.0           7.0
# 140 2020-04-18    Estonia     1326739       1512.0          38.0
# 141 2020-04-18      Malta      441811        426.0           3.0
# 144 2020-04-18    Iceland      341743       1760.0           9.0
#
#      Total_Recovered  Percentage_Positive_Population
# 0            68269.0                        0.222903
# 138             86.0                        0.001185
# 140            162.0                        0.113964
# 141             99.0                        0.096421
# 144           1291.0                        0.515007

# %% [markdown]
# ## Analyzing the basics and looking into .
#  After reading thrugh an [article](https://www.bbc.com/news/world-52103747) by the BBC, it was noticed that most of the nationalised lockdown occured during months of April to June. Thus, we shall look into how some of the most populated countries did during the month of April to June versus July to Spetember. Thus, we now start our Graphical and non graphical analysis.
#
#  **The two main Research Question we will be focusing on:**
#  #### 1. Which time period had a more significant rise in total cases when comapred to each other?
#  #### 2. Was the positive patients percentage in these two time frames diffrent or did they still remain the same?

# %%
## Starting with Months April to May, non-graphical analysis.
## we first see the number of total cases from april to may, then we check for may to june, and wehen we
## find the difference we shall be able to compare both 

# April to May
ApriltoMay = df[(df['Date']>'2020-04-18') & (df['Date']<='2020-05-18')]
ApriltoMay.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)

ApriltoMay.head()
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/1224125826.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ApriltoMay.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
#            Date Country  Population  Total_Cases  Total_Deaths  \
# 6390 2020-05-18     USA   331441624    1550294.0       91981.0
# 6177 2020-05-17     USA   331441624    1527664.0       90978.0
# 5964 2020-05-16     USA   331441624    1507773.0       90113.0
# 5751 2020-05-15     USA   331441624    1484285.0       88507.0
# 5538 2020-05-14     USA   331441624    1457593.0       86912.0
#
#       Total_Recovered  Percentage_Positive_Population
# 6390         356383.0                        0.467743
# 6177         346389.0                        0.460915
# ...

# %%
# May to June
MaytoJune = df[(df['Date']>'2020-05-19') & (df['Date']<='2020-06-18')]
MaytoJune.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
MaytoJune.head()
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/763444508.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MaytoJune.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
#             Date Country  Population  Total_Cases  Total_Deaths  \
# 12993 2020-06-18     USA   331441624    2263651.0      120688.0
# 12780 2020-06-17     USA   331441624    2234471.0      119941.0
# 12567 2020-06-16     USA   331441624    2208400.0      119132.0
# 12354 2020-06-15     USA   331441624    2182950.0      118283.0
# 12141 2020-06-14     USA   331441624    2162144.0      117853.0
#
#        Total_Recovered  Percentage_Positive_Population
# 12993         930994.0                        0.682971
# 12780         918796.0                        0.674167
# ...

# %%
# July to Spetember

# July to August 
JulytoAugust = df[(df['Date']>'2020-07-18') & (df['Date']<='2020-08-18')]
JulytoAugust.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
JulytoAugust
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/944435598.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JulytoAugust.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
#             Date       Country  Population  Total_Cases  Total_Deaths  \
# 25986 2020-08-18           USA   331441624    5655974.0      175074.0
# 25773 2020-08-17           USA   331441624    5612027.0      173716.0
# 25560 2020-08-16           USA   331441624    5566632.0      173128.0
# 25347 2020-08-15           USA   331441624    5529789.0      172606.0
# 25134 2020-08-14           USA   331441624    5476266.0      171535.0
# ...          ...           ...         ...          ...           ...
# 19989 2020-07-20  Saint Martin       38812         46.0           3.0
# ...

# %%
# August to September
AugusttoSeptember = df[(df['Date']>'2020-08-19') & (df['Date']<='2020-09-18')]
AugusttoSeptember.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
AugusttoSeptember
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/2836584019.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AugusttoSeptember.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
#             Date Country  Population  Total_Cases  Total_Deaths  \
# 32589 2020-09-18     USA   331441624    6925941.0      203171.0
# 32376 2020-09-17     USA   331441624    6874596.0      202213.0
# 32163 2020-09-16     USA   331441624    6828301.0      201348.0
# 31950 2020-09-15     USA   331441624    6788147.0      200197.0
# 31737 2020-09-14     USA   331441624    6749289.0      199000.0
# ...          ...     ...         ...          ...           ...
# 30017 2020-09-05    Fiji      897910         31.0           2.0
# 29378 2020-09-02    Fiji      897910         29.0           2.0
# ...

# %%
# Now we compare the total number of cases by subtarcting the total number of cases beteween the month periods and see
# which time period had the most significant rise in case
m1 = ApriltoMay.sum(axis=0,skipna=True)
m2 = MaytoJune.sum(axis=0,skipna=True)
m3 = JulytoAugust.sum(axis=0,skipna=True)
m4 = AugusttoSeptember.sum(axis=0,skipna=True)
p1 = m2["Total_Cases"] - m1["Total_Cases"]
p2 =  m4["Total_Cases"] - m3["Total_Cases"]
print(f" Difference in Cases from time period April to June: {p1}")
print(f" Difference in Cases from time period July to August:{p2}")
# Out:
#  Difference in Cases from time period April to June: 83080516.0
#  Difference in Cases from time period July to August:206915789.0

# %%
#Now for a Visual representation with selescting a single date amongst the folowing time period 
# As per laws of Median, we take the middle value of our analysis dataset, thus we shall pick the 
# From the time Period April to June, we take 2020-05-18
# From the time Period July to September, we take 2020-08-18

# %%
#May
may = df[(df['Date']>'2020-05-18') & (df['Date']<='2020-05-19')]
may.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
sns.pairplot(may)
plt.show()
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/250398001.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   may.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)

# %%
#May to check top 5 Countries
may5= may.head(5)
sns.barplot("Country",y = "Percentage_Positive_Population",data=may5)
# Out:
# c:\programdata\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Percentage_Positive_Population'>

# %%
#August
aug = df[(df['Date']>'2020-08-18') & (df['Date']<='2020-08-19')]
aug.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)
sns.pairplot(aug)
plt.show()
# Out:
# C:\Users\Yatharth Mathur\AppData\Local\Temp/ipykernel_30892/2449010721.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aug.sort_values("Total_Cases",axis=0,ascending=False,inplace=True)

# %%
#August to check top 5 Countries
aug5= aug.head(5)
sns.barplot("Country",y = "Percentage_Positive_Population",data=aug5)
plt.show()
# Out:
# c:\programdata\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Analysis
#  ## Answering the Research Questions based on both Graphical and Non Graphical anlaysis
#  #### 1. Which time period had a more significant rise in total cases when comapred to each other?
#  Ans: When compard the two timelines, ie. times of nationalised lockdown and non-nationalised lockdown, we notice that the countries have had a lesser population impacted in the months o April to June. On the first bar graph we notice only The United States of America had a significant cases surge and had a good ammount of population getting impacted. Even if you look at teh pair plot you will observe that Total Cases had a significant rise too from the two time periods. But, few values have remained somehwhat constant. we notice that the Total Recovered have been equally high, and the number of deaths have also been showing similiar outcomes. Thus we can conlclude, Lockdowns helped us keep the cases low, but as the countries eased lockdown lawas the cases surged ina many third world countries specifically. Statistics suggest as per above analysis, months beteween had a growth of 83080516 cases, but between July to September teh increase in cases were 206915789.0 more. This differnce in growth prooved that nationalised lockdowns in countries were effective.
#  #### 2. Was the positive patients percentage in these two time frames diffrent or did they still remain the same?
#  No, as we see the bar graphs, the Percentage value grew significantly after the lockdown laws were easd out in many countries. The population rise also did not play that much of a significant role, becasue the number of cases going up were way higher.This, just prooves that the lockdown had a significant impact on keeping cases low in the overall percentage of population.
#
# #### From the cleaning and wrangling of data we have taken values of 144 countries and below shows all the other details

# %%
df.count()
# Out:
# Date                              18025
# Country                           18025
# Population                        18025
# Total_Cases                       18025
# Total_Deaths                      18025
# Total_Recovered                   18025
# Percentage_Positive_Population    18025
# dtype: int64

# %%
df.describe(include=[np.number])
# Out:
#          Population   Total_Cases   Total_Deaths  Total_Recovered  \
# count  1.802500e+04  1.802500e+04   18025.000000     1.802500e+04
# mean   4.672500e+07  1.074471e+05    4072.359667     6.882971e+04
# std    1.563426e+08  4.791362e+05   16179.436927     3.047804e+05
# min    4.993000e+03  1.100000e+01       0.000000     2.000000e+00
# 25%    2.964505e+06  1.805000e+03      28.000000     9.080000e+02
# 50%    9.939517e+06  8.987000e+03     184.000000     4.703000e+03
# 75%    3.700833e+07  4.561300e+04    1150.000000     2.701700e+04
# max    1.439324e+09  7.009844e+06  204118.000000     4.392650e+06
#
#        Percentage_Positive_Population
# count                    18025.000000
# mean                         0.320773
# std                          0.535814
# min                          0.000088
# 25%                          0.032161
# 50%                          0.118520
# 75%                          0.368141
# max                          4.394037

# %%
df.describe(include=[object])
# Out:
#         Country
# count     18025
# unique      156
# top     Germany
# freq        156
